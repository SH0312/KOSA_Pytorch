# %% [markdown]
# <a href="https://colab.research.google.com/github/SH0312/KOSA_Pytorch/blob/main/Resnet34-3class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How to Train a Custom Resnet34 for Image Classification in fastai and PyTorch
# Can I computer tell the diffence between a daisy and a dandelion? The answer is yes
#
#
# This tutorial shows you how to train a state of the art image classification model with Resnet, in PyTorch, using the fastai library.
#
# ### Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the blog post on [how to train Resnet34 image classification model](https://blog.roboflow.ai/how-to-train-yolov5-on-a-custom-dataset/), concurrently.
#
# ### Steps Covered in this Tutorial
#
# In this tutorial, we will walk through the steps required to train Resnet to recognize your custom classes. We use a [public flowers classification dataset](
# https://public.roboflow.com/classification/flowers_classification), which is open source and free to use. You can also use this notebook on your own data.
#
# To train our custom classifier we take the following steps:
#
# * Install fastai dependencies
# * Expand our training set via augmentations in Roboflow
# * Download custom classificatio data from Roboflow
# * Download pretrained Resnet Models
# * Run frozen Resent training in fastai
# * Find a favorable learning rate
# * Run unfrozen training
# * Inspect our model's evaluation metrics
# * Run Resnet inference on test images
# * Export saved Resnet weights for future inference
#
#
#
# ### **About**
#
# [Roboflow](https://roboflow.ai) enables teams to deploy custom computer vision models quickly and accurately. Convert data from to annotation format, assess dataset health, preprocess, augment, and more. It's free for your first 1000 source images.
#
# #### ![Roboflow Workmark](https://i.imgur.com/WHFqYSJ.png)

# %% [markdown]
# # Install fastai dependencies

# %%
# !ls -l
# Out:
# total 8
# drwx------ 6 root root 4096 May 25 07:31 drive
# drwxr-xr-x 1 root root 4096 May  6 13:44 sample_data

# %%
# !cp /content/drive/MyDrive/3class-augmented.zip .

# %%
# !unzip ./3class-augmented.zip

# %%
# !ls -l
# Out:
# total 3844
# drwxr-xr-x 5 root root    4096 May 25 07:32 3class-augmented
# -rw------- 1 root root 3922018 May 25 07:32 3class-augmented.zip
# drwx------ 6 root root    4096 May 25 07:31 drive
# drwxr-xr-x 1 root root    4096 May  6 13:44 sample_data

# %%
# !pip install fastai

# %%
from fastai.vision import *

# %% [markdown]
# # Downlaod Custom Classification Data From Roboflow

# %%
#build fastai dataset loader
np.random.seed(42)
#fastai automatically factors the ./train and ./valid folders into seperate datasets
#more details https://docs.fast.ai/vision.data.html#ImageDataLoaders.from_folder
path = Path('/content/3class-augmented')
data = ImageDataBunch.from_folder(path, size=224, num_workers=2).normalize(imagenet_stats)

# %%
#double check the data classes
data.classes
# Out:
# ['paper', 'rock', 'scissors']

# %%
#take a peak at the batch to make sure things were loaded correctly
data.show_batch(rows=3, figsize=(7, 8))

# %% [markdown]
# # Set up fastai Resnet model

# %%
from fastai.metrics import error_rate # 1 - accuracy
learn = create_cnn(data, models.resnet50, metrics=error_rate)
# Out:
# /usr/local/lib/python3.7/dist-packages/fastai/vision/learner.py:109: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# HBox(children=(FloatProgress(value=0.0, max=102502400.0), HTML(value='')))

# %%
#print network layers
learn

# %% [markdown]
# # Train Custom Resnet Image Classifier

# %%
from fastai.callbacks import *
early_stop = EarlyStoppingCallback(learn, patience=20)
save_best_model = SaveModelCallback(learn, name='best_resnet50')

# %%
#frozen training step
defaults.device = torch.device('cuda') # makes sure the gpu is used
learn.fit_one_cycle(1, callbacks=[early_stop, save_best_model])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.582299</td>
#       <td>0.051667</td>
#       <td>0.027778</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.05166689306497574.

# %%
#load best model from frozen training
learn.load('best_resnet50')

# %%
learn.unfreeze()

# %%
def find_appropriate_lr(model:Learner, lr_diff:int = 15, loss_threshold:float = .05, adjust_value:float = 1, plot:bool = False) -> float:
    #Run the Learning Rate Finder
    model.lr_find()
    
    #Get loss values and their corresponding gradients, and get lr values
    losses = np.array(model.recorder.losses)
    min_loss_index = np.argmin(losses)
    
    
    #loss_grad = np.gradient(losses)
    lrs = model.recorder.lrs
    
    #return the learning rate that produces the minimum loss divide by 10   
    return lrs[min_loss_index] / 10

# %%
optimal_lr = find_appropriate_lr(learn)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='9' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       44.44% [4/9 00:29<00:36]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.064163</td>
#       <td>#na#</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.052417</td>
#       <td>#na#</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.033113</td>
#       <td>#na#</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.022201</td>
#       <td>#na#</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8' class='' max='12' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [8/12 00:04<00:02 0.0339]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(50, max_lr=slice(optimal_lr/10, optimal_lr), callbacks=[early_stop, save_best_model])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.046133</td>
#       <td>0.005988</td>
#       <td>0.000000</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.040828</td>
#       <td>0.007202</td>
#       <td>0.000000</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.026207</td>
#       <td>0.002201</td>
#       <td>0.000000</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.017341</td>
#       <td>0.001098</td>
#       <td>0.000000</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.012782</td>
#       <td>0.000859</td>
#       <td>0.000000</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.009318</td>
#       <td>0.001312</td>
#       <td>0.000000</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.007288</td>
#       <td>0.000748</td>
#       <td>0.000000</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.005480</td>
#       <td>0.000171</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.004537</td>
#       <td>0.001296</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.003542</td>
#       <td>0.000987</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.002777</td>
#       <td>0.000494</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.002193</td>
#       <td>0.000531</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.001767</td>
#       <td>0.000327</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.001389</td>
#       <td>0.000318</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.001088</td>
#       <td>0.000329</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.000856</td>
#       <td>0.000268</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.000672</td>
#       <td>0.000345</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.000536</td>
#       <td>0.000360</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.000425</td>
#       <td>0.000256</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.000336</td>
#       <td>0.000297</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.000272</td>
#       <td>0.000275</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.000216</td>
#       <td>0.000246</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.000192</td>
#       <td>0.000250</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.000152</td>
#       <td>0.000208</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.000123</td>
#       <td>0.000187</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.000099</td>
#       <td>0.000106</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.000085</td>
#       <td>0.000092</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.000071</td>
#       <td>0.000111</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.000056</td>
#       <td>0.000091</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.000045</td>
#       <td>0.000092</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.000038</td>
#       <td>0.000087</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.000031</td>
#       <td>0.000103</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.000026</td>
#       <td>0.000092</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.000022</td>
#       <td>0.000094</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.000022</td>
#       <td>0.000089</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.000025</td>
#       <td>0.000078</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.000020</td>
#       <td>0.000061</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.000022</td>
#       <td>0.000069</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.000023</td>
#       <td>0.000059</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.000019</td>
#       <td>0.000049</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.000018</td>
#       <td>0.000060</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.000015</td>
#       <td>0.000084</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.000012</td>
#       <td>0.000070</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.000011</td>
#       <td>0.000054</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.000009</td>
#       <td>0.000051</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.000012</td>
#       <td>0.000041</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.000010</td>
#       <td>0.000052</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.000012</td>
#       <td>0.000047</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.000010</td>
#       <td>0.000056</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.000009</td>
#       <td>0.000067</td>
#       <td>0.000000</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.005987636279314756.
# Better model found at epoch 2 with valid_loss value: 0.0022014796268194914.
# Better model found at epoch 3 with valid_loss value: 0.001097933854907751.
# Better model found at epoch 4 with valid_loss value: 0.0008586564799770713.
# Better model found at epoch 6 with valid_loss value: 0.0007482717628590763.
# Better model found at epoch 7 with valid_loss value: 0.00017126224702224135.
# Better model found at epoch 25 with valid_loss value: 0.00010584784467937425.
# Better model found at epoch 26 with valid_loss value: 9.242732630809769e-05.
# Better model found at epoch 28 with valid_loss value: 9.062638855539262e-05.
# Better model found at epoch 30 with valid_loss value: 8.686705405125394e-05.
# Better model found at epoch 35 with valid_loss value: 7.788490620441735e-05.
# Better model found at epoch 36 with valid_loss value: 6.0572856455110013e-05.
# Better model found at epoch 38 with valid_loss value: 5.935272929491475e-05.
# Better model found at epoch 39 with valid_loss value: 4.863294816459529e-05.
# Better model found at epoch 45 with valid_loss value: 4.114588227821514e-05.

# %%
learn.load('best_resnet50')

# %% [markdown]
# # Evaluate Classifier Performance

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(9, figsize=(15,15))

# %%
#run inference on test images
import glob
from IPython.display import Image, display

model = learn.model
model = model.cuda()
for imageName in glob.glob('/content/s2.jpg'):
    print(imageName)
    img = open_image(imageName)
    prediction = learn.predict(img)
    #print(prediction)
    print(prediction[0])
    display(Image(filename=imageName))
    print("\n")

# %% [markdown]
# # Save custom classification model for future use

# %%
#model is automatically saved with the "save_best_model" callback
# %ls models/
# Out:
# best_resnet34.pth  tmp.pth

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
files.download('./models/best_resnet34.pth')
